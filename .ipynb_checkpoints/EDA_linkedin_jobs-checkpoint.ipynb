# %% [markdown]
# # EDA Project: Investigate a Dataset (Replace this with something more specific!)
# # By Raghad Althunayyan
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > In this project, I will clean and analyze exploratory data for LinkedIn job postings based in Saudi (Jan 2020 to Mar 2021) to answer some of the questions.
#
# > Note: Data was collected by data engineer Majed Al Hulayel.
# >
#
# > Question/need:
#
# >1- What are the companies that may hire T5 Bootcamp graduates?
#
# >2- what is the Level high required?
#
# >3- What is the direction of the labor market?
#
# >4- What is the peak month of job posting?.

# %%
# import statements for all of the packages that I plan to use.
import pandas as pd
import re
import os
import numpy as np
import seaborn as sb
sb.set()
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# # Data Wrangling
#
# >  In this section of the report, I will load in the data, check for cleanliness, and then trim and clean our dataset for analysis. I will document my steps carefully and justify cleaning decisions.
#
# <li><a href="#Gathering">Data Gathering</a></li>
# <li><a href="#Assesment">Data Assesment</a></li>
# <li><a href="#Cleaning">Data Cleaning</a></li>

# %% [markdown]
# <a id='Gathering'></a>
# ### Data Gathering

# %%
# Load data and print out a few lines.
#df= pd.read_csv("Data4.csv", error_bad_lines=False) to remove the warning lines put on_bad_lines  = 'skip'
df= pd.read_csv("linkedin jobs.csv",  error_bad_lines=False)
df.head(5)
# Out:
# b'Skipping line 146: expected 13 fields, saw 18\nSkipping line 327: expected 13 fields, saw 14\nSkipping line 337: expected 13 fields, saw 32\nSkipping line 369: expected 13 fields, saw 18\nSkipping line 370: expected 13 fields, saw 16\nSkipping line 426: expected 13 fields, saw 18\nSkipping line 465: expected 13 fields, saw 22\nSkipping line 524: expected 13 fields, saw 23\nSkipping line 544: expected 13 fields, saw 32\nSkipping line 635: expected 13 fields, saw 14\nSkipping line 647: expected 13 fields, saw 15\nSkipping line 654: expected 13 fields, saw 14\nSkipping line 664: expected 13 fields, saw 32\nSkipping line 690: expected 13 fields, saw 14\nSkipping line 739: expected 13 fields, saw 32\nSkipping line 743: expected 13 fields, saw 17\nSkipping line 749: expected 13 fields, saw 17\nSkipping line 788: expected 13 fields, saw 14\nSkipping line 812: expected 13 fields, saw 27\nSkipping line 828: expected 13 fields, saw 43\nSkipping line 923: expected 13 fields, saw 14\nSkipping line 930: expected 13 fields, saw 18\nSkipping line 993: expected 13 fields, saw 67\nSkipping line 1021: expected 13 fields, saw 16\nSkipping line 1039: expected 13 fields, saw 17\nSkipping line 1049: expected 13 fields, saw 24\nSkipping line 1155: expected 13 fields, saw 16\nSkipping line 1180: expected 13 fields, saw 28\nSkipping line 1193: expected 13 fields, saw 18\nSkipping line 1284: expected 13 fields, saw 24\nSkipping line 1305: expected 13 fields, saw 18\nSkipping line 1346: expected 13 fields, saw 24\nSkipping line 1367: expected 13 fields, saw 18\nSkipping line 1371: expected 13 fields, saw 18\nSkipping line 1415: expected 13 fields, saw 18\nSkipping line 1446: expected 13 fields, saw 18\nSkipping line 1460: expected 13 fields, saw 23\nSkipping line 1471: expected 13 fields, saw 18\nSkipping line 1488: expected 13 fields, saw 18\nSkipping line 1490: expected 13 fields, saw 22\nSkipping line 1499: expected 13 fields, saw 23\nSkipping line 1518: expected 13 fields, saw 18\nSkipping line 1530: expected 13 fields, saw 18\nSkipping line 1536: expected 13 fields, saw 23\nSkipping line 1746: expected 13 fields, saw 15\nSkipping line 1862: expected 13 fields, saw 20\nSkipping line 1926: expected 13 fields, saw 30\nSkipping line 1990: expected 13 fields, saw 28\nSkipping line 2035: expected 13 fields, saw 17\nSkipping line 2036: expected 13 fields, saw 15\nSkipping line 2148: expected 13 fields, saw 15\nSkipping line 2224: expected 13 fields, saw 73\nSkipping line 2313: expected 13 fields, saw 28\nSkipping line 2337: expected 13 fields, saw 43\nSkipping line 2349: expected 13 fields, saw 23\nSkipping line 2387: expected 13 fields, saw 36\nSkipping line 2391: expected 13 fields, saw 18\nSkipping line 2436: expected 13 fields, saw 23\nSkipping line 2454: expected 13 fields, saw 15\nSkipping line 2476: expected 13 fields, saw 15\nSkipping line 2499: expected 13 fields, saw 23\nSkipping line 2512: expected 13 fields, saw 36\nSkipping line 2574: expected 13 fields, saw 16\nSkipping line 2658: expected 13 fields, saw 90\nSkipping line 2689: expected 13 fields, saw 17\nSkipping line 2766: expected 13 fields, saw 21\nSkipping line 2860: expected 13 fields, saw 33\nSkipping line 2868: expected 13 fields, saw 22\nSkipping line 2876: expected 13 fields, saw 18\nSkipping line 2905: expected 13 fields, saw 35\nSkipping line 2946: expected 13 fields, saw 19\nSkipping line 3032: expected 13 fields, saw 19\nSkipping line 3046: expected 13 fields, saw 19\nSkipping line 3054: expected 13 fields, saw 22\nSkipping line 3057: expected 13 fields, saw 35\nSkipping line 3082: expected 13 fields, saw 35\nSkipping line 3140: expected 13 fields, saw 14\nSkipping line 3220: expected 13 fields, saw 23\nSkipping line 3221: expected 13 fields, saw 50\nSkipping line 3230: expected 13 fields, saw 46\nSkipping line 3242: expected 13 fields, saw 23\nSkipping line 3248: expected 13 fields, saw 45\nSkipping line 3265: expected 13 fields, saw 23\nSkipping line 3273: expected 13 field ...
# b'Skipping line 67948: expected 13 fields, saw 20\nSkipping line 67952: expected 13 fields, saw 16\nSkipping line 67958: expected 13 fields, saw 21\nSkipping line 67970: expected 13 fields, saw 20\nSkipping line 67971: expected 13 fields, saw 16\nSkipping line 67977: expected 13 fields, saw 20\nSkipping line 67993: expected 13 fields, saw 44\nSkipping line 68015: expected 13 fields, saw 14\nSkipping line 68069: expected 13 fields, saw 50\nSkipping line 68111: expected 13 fields, saw 20\nSkipping line 68117: expected 13 fields, saw 132\nSkipping line 68137: expected 13 fields, saw 16\nSkipping line 68150: expected 13 fields, saw 16\nSkipping line 68164: expected 13 fields, saw 52\nSkipping line 68183: expected 13 fields, saw 16\nSkipping line 68204: expected 13 fields, saw 72\nSkipping line 68205: expected 13 fields, saw 42\nSkipping line 68207: expected 13 fields, saw 16\nSkipping line 68247: expected 13 fields, saw 16\nSkipping line 68250: expected 13 fields, saw 16\nSkipping line 68252: expected 13 fields, saw 57\nSkipping line 68261: expected 13 fields, saw 41\nSkipping line 68280: expected 13 fields, saw 45\nSkipping line 68313: expected 13 fields, saw 52\nSkipping line 68315: expected 13 fields, saw 16\nSkipping line 68334: expected 13 fields, saw 20\nSkipping line 68345: expected 13 fields, saw 16\nSkipping line 68364: expected 13 fields, saw 20\nSkipping line 68367: expected 13 fields, saw 53\nSkipping line 68375: expected 13 fields, saw 20\nSkipping line 68383: expected 13 fields, saw 72\nSkipping line 68394: expected 13 fields, saw 14\nSkipping line 68409: expected 13 fields, saw 16\nSkipping line 68420: expected 13 fields, saw 22\nSkipping line 68430: expected 13 fields, saw 23\nSkipping line 68439: expected 13 fields, saw 36\nSkipping line 68490: expected 13 fields, saw 19\nSkipping line 68608: expected 13 fields, saw 16\nSkipping line 68609: expected 13 fields, saw 16\nSkipping line 68622: expected 13 fields, saw 29\nSkipping line 68656: expected 13 fields, saw 23\nSkipping line 68747: expected 13 fields, saw 52\nSkipping line 68823: expected 13 fields, saw 45\nSkipping line 68826: expected 13 fields, saw 14\nSkipping line 68828: expected 13 fields, saw 59\nSkipping line 68829: expected 13 fields, saw 59\nSkipping line 68848: expected 13 fields, saw 33\nSkipping line 68883: expected 13 fields, saw 57\nSkipping line 68900: expected 13 fields, saw 23\nSkipping line 68910: expected 13 fields, saw 42\nSkipping line 68930: expected 13 fields, saw 29\nSkipping line 68989: expected 13 fields, saw 75\nSkipping line 69064: expected 13 fields, saw 33\nSkipping line 69070: expected 13 fields, saw 21\nSkipping line 69075: expected 13 fields, saw 38\nSkipping line 69139: expected 13 fields, saw 21\nSkipping line 69167: expected 13 fields, saw 42\nSkipping line 69195: expected 13 fields, saw 61\nSkipping line 69205: expected 13 fields, saw 42\nSkipping line 69257: expected 13 fields, saw 62\nSkipping line 69263: expected 13 fields, saw 17\nSkipping line 69279: expected 13 fields, saw 34\nSkipping line 69283: expected 13 fields, saw 37\nSkipping line 69290: expected 13 fields, saw 47\nSkipping line 69328: expected 13 fields, saw 42\nSkipping line 69395: expected 13 fields, saw 19\nSkipping line 69431: expected 13 fields, saw 34\nSkipping line 69435: expected 13 fields, saw 19\nSkipping line 69497: expected 13 fields, saw 19\nSkipping line 69548: expected 13 fields, saw 47\nSkipping line 69568: expected 13 fields, saw 16\nSkipping line 69582: expected 13 fields, saw 23\nSkipping line 69586: expected 13 fields, saw 62\nSkipping line 69591: expected 13 fields, saw 19\nSkipping line 69671: expected 13 fields, saw 40\nSkipping line 69715: expected 13 fields, saw 37\nSkipping line 69730: expected 13 fields, saw 16\nSkipping line 69737: expected 13 fields, saw 42\nSkipping line 69768: expected 13 fields, saw 33\nSkipping line 69811: expected 13 fields, saw 52\nSkipping line 69824: expected 13 fields, saw 42\nSkipping line 69850: expecte ...
# /Users/raghadalthunayan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   position_id                           Position  \
# 0       51791  Head of Branding Governance Unit
# 1       51792                Document Controller
# 2       51793     Employee Engagement Specialist
# 3       51794        Strategic Workforce Analyst
# 4       51795      Account Manager, GPS – Riyadh
#
#                          Company              Location                 Date  \
# 0                     Riyad Bank  Riyadh, Saudi Arabia  2020-01-06 00:00:00
# 1      Confidential,Confidential  Riyadh, Saudi Arabia  2020-01-06 00:00:00
# 2                        PepsiCo  Riyadh, Saudi Arabia  2020-01-06 00:00:00
# 3  Saudi Air Navigation Services  Jeddah, Saudi Arabia  2020-01-06 00:00:00
# 4                             EY  Riyadh, Saudi Arabia  2020-01-06 00:00:00
#
#               Level                       Job_Function  \
# 0  Mid-Senior level        ['Marketing', 'Management']
# 1         Associate                               ['']
# 2  Mid-Senior level                ['Human Resources']
# 3  Mid-Senior level                               ['']
# 4    Not Applicable  ['Sales', 'Business Development']
#
#                                  Industry  \
# 0                             ['Banking']
# 1           ['Government Administration']
# 2  ['Consumer Goods', 'Food & Beverages']
# 3                ['Aviation & Aerospace']
# 4    ['Accounting', 'Financial Services']
#
#                                          Description  \
# 0                                                NaN
# 1  Document Controller- (Saudi candidates only)  ...
# 2  Auto req ID: 199735BRJob DescriptionPepsiCo Sa...
# 3  Role PurposeTo conduct workforce analysis to s...
# 4  In a business where are our people are our pro...
#
#                                              Link linkedin_id  \
# 0  https://www.linkedin.com/jobs/view/1632901070/  1632901070
# 1  https://www.linkedin.com/jobs/view/1628497696/  1628497696
# 2  https://www.linkedin.com/jobs/view/1666951758/  1666951758
# 3  https://www.linkedin.com/jobs/view/1671138260/  1671138260
# 4  https://www.linkedin.com/jobs/view/1670725370/  1670725370
#
#   company_linkedin_url experience
# 0                  NaN        NaN
# 1                  NaN          3
# 2                  NaN          1
# 3                  NaN        NaN
# 4                  NaN          7

# %% [markdown]
# <a id='Assesment'></a>
# ### Data Assesment
# - Perform operations to inspect data types
# - Look for instances of missing or possibly errant data.

# %%
# inspect dataset shape.
df.shape

# inspect data type for each column.
df.dtypes

# inspect data set for missing values
df.isna().sum()
# Out:
# position_id                 0
# Position                 2444
# Company                  2453
# Location                 2479
# Date                     2756
# Level                   17208
# Job_Function             2445
# Industry                 2445
# Description              5633
# Link                     2640
# linkedin_id              2760
# company_linkedin_url    50534
# experience              55346
# dtype: int64

# %%
#Visulaization of missing values
fig, ax = plt.subplots(figsize=(9,6))
sb.heatmap(df.isnull(), cbar=False, cmap="YlGnBu_r")
plt.show()

# %%
# inspect each columns names.
df.columns
# Out:
# Index(['position_id', 'Position', 'Company', 'Location', 'Date', 'Level',
#        'Job_Function', 'Industry', 'Description', 'Link', 'linkedin_id',
#        'company_linkedin_url', 'experience'],
#       dtype='object')

# %%
df.Position.value_counts()[df.Position.value_counts().values>10].index
# Out:
# Index(['Care Assistant', 'Store Associate', 'Accountant', 'Project Manager',
#        'Graphic Designer', 'Business Development Manager', 'Sales Manager',
#        'Sales Executive', 'Marketing Manager', 'Account Manager',
#        ...
#        'Python Developer', 'Sales Assistant', 'Property Consultant',
#        'Business Development Coordinator', 'Materials Engineer',
#        'Credit Manager', 'Sales Business Development',
#        'Consultant - Geotechnical', 'Digital Marketing Executive',
#        'Intern Bachelors Systems Eng - Saudi National'],
#       dtype='object', length=1258)

# %%
# Explore column 'company' values for errant data.
df.Company.value_counts()[df.Company.value_counts().values>13].index
# Out:
# Index(['Allied Healthcare', 'Confidential', 'Parsons Corporation',
#        'Landmark Arabia', 'Crossover for Work', 'Amazon', 'AFRY',
#        'PwC Middle East', 'PepsiCo', 'AllRetailJobs.com',
#        ...
#        'SAP Middle East & North Africa', 'Chess Tag', 'Hala Fakher',
#        'Awtad Anwa Trading Est. Titanium', 'Systems Networks Company',
#        'Middle East Specialized Cables (MESC)',
#        'Al Tahaluf Real Estate Company LLC شركة التحالف العقاري ذ.م.م',
#        'Progress Personnel Limited. Executive Recruitment across KSA and the GCC',
#        'Mag Areospace', 'Indman Management Consultants Private Limited'],
#       dtype='object', length=1234)

# %%
# Explore location values that repeated more than 4 times for errant data.
df.Location.value_counts()[df.Location.value_counts().values>4].index
# Out:
# Index(['Riyadh, Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'Saudi Arabia',
#        'Jeddah, Makkah, Saudi Arabia', 'Jiddah, Makkah, Saudi Arabia',
#        'Dammam, Eastern, Saudi Arabia', 'Al Khobar, Eastern, Saudi Arabia',
#        'Makkah Region', 'Medina, Al Madinah, Saudi Arabia', 'Riyadh Region',
#        ...
#        '2021-08-06 00:00:00', '2021-07-20 00:00:00',
#        'New Industrial City, Riyadh, Saudi Arabia',
#        'Al Rayyan, Makkah, Saudi Arabia', '2021-11-01 00:00:00', 'Entry level',
#        'Al Dawadmi, Riyadh, Saudi Arabia', '2021-10-20 00:00:00',
#        '2021-10-09 00:00:00',
#        'King Abdullah University of Science & Technology, Makkah, Saudi Arabia'],
#       dtype='object', length=312)

# %%
# Explore location values that repeated less than 4 times for errant data.
df.Location.value_counts()[df.Location.value_counts().values<4].index
# Out:
# Index(['Al Waha, Riyadh, Saudi Arabia', '‘Afīf, Riyadh, Saudi Arabia',
#        'Al Jazirah, Riyadh, Saudi Arabia', 'Al Majma, Najran, Saudi Arabia',
#        'United States', 'Al Rahmaniyah, Riyadh, Saudi Arabia',
#        '2021-09-03 00:00:00', 'Al Madinah, Northern Frontier, Saudi Arabia',
#        '2021-11-09 00:00:00', 'Al Ulayah Al Gharbiyah, Riyadh, Saudi Arabia',
#        ...
#        'Saudi, Riyadh, Saudi Arabia',
#        'King Fahd Military Medical Complex, Eastern, Saudi Arabia',
#        '2021-10-17 00:00:00', 'Al Rayan, Riyadh, Saudi Arabia',
#        'Al Hasah, Al Qasim, Saudi Arabia', 'Thadiq, Riyadh, Saudi Arabia',
#        'Alfaysalyah, Najran, Saudi Arabia',
#        'KhamÄ«s MushayÅ£, 'Asir, Saudi Arabia', 'Bahra, Makkah, Saudi Arabia',
#        'Al Darb, Jizan, Saudi Arabia'],
#       dtype='object', length=257)

# %%
# Explore column 'location' values that repeated 4 times for errant data
df.Location.value_counts()[df.Location.value_counts().values==4].index
# Out:
# Index(['‘Usfān, Makkah, Saudi Arabia', 'Sabya, Jizan, Saudi Arabia',
#        '2021-09-26 00:00:00', 'Sak훮kah, Al Jawf, Saudi Arabia',
#        'Al Majmaâ€˜ah, Riyadh, Saudi Arabia', '2021-10-18 00:00:00',
#        'Hawtat Bani Tameem, Riyadh, Saudi Arabia',
#        'Alhawiyah, Makkah, Saudi Arabia', '2021-08-28 00:00:00',
#        'Al Nakheel, Riyadh, Saudi Arabia', 'Khurais, Eastern, Saudi Arabia',
#        'Muhayal, 'Asir, Saudi Arabia', 'Salam, Al Qasim, Saudi Arabia',
#        'Ḩuraymila, Saudi Arabia', 'Al Omrah Al Jaddeda, Makkah, Saudi Arabia',
#        '2021-08-16 00:00:00', '2021-11-07 00:00:00',
#        'Ain Shams, Makkah, Saudi Arabia',
#        'Saudi Aramco, Eastern, Saudi Arabia', '99999', '2021-09-27 00:00:00',
#        'Dammam 3Rd Industrial City, Eastern, Saudi Arabia',
#        '2021-11-08 00:00:00', '2021-09-02 00:00:00',
#        'Al Malga, Riyadh, Saudi Arabia', '2021-10-14 00:00:00',
#        '2021-11-03 00:00:00'],
#       dtype='object')

# %%
df.Date.value_counts().index
# Out:
# Index(['2020-01-28 00:00:00', '2020-01-21 00:00:00', '2020-01-13 00:00:00',
#        '2020-02-07 00:00:00', '2020-01-06 00:00:00', '2020-02-29 00:00:00',
#        '2020-02-22 00:00:00', '2020-02-15 00:00:00', '2020-12-11 00:00:00',
#        '2020-03-21 00:00:00',
#        ...
#        '['Quality Assurance and Customer Service']', '2020-06-09 16:55:29',
#        '2020-08-22 18:00:57', '2020-05-24 03:00:25', '2020-04-27 06:31:36',
#        '['Information Technology, Consulting, and Engineering']',
#        'Riyadh, Saudi Arabia', '2020-06-18 09:44:07', '2020-06-21 12:04:58',
#        '2020-04-23 18:00:08'],
#       dtype='object', length=1447)

# %%
# Explore column 'level' values for errant data.
df.Level.value_counts()[df.Level.value_counts().values>1].index
# Out:
# Index(['Entry level', 'Mid-Senior level', 'Associate', 'Not Applicable',
#        'Director', 'Executive', 'Internship', '[]', '['Other']',
#        '['Management and Manufacturing']', '['Information Technology']',
#        '['Sales and Business Development']',
#        '['Engineering and Information Technology']', '['Sales']',
#        '['Project Management and Information Technology']',
#        '['Accounting/Auditing and Finance']', '['Human Resources']',
#        '['Customer Service and Information Technology']', '['Administrative']',
#        '['Supply Chain']', '['Health Care Provider']',
#        '['Business Development and Sales']', '['Engineering']',
#        '['Research, Analyst, and Information Technology']',
#        '['Quality Assurance']', '['Purchasing and Supply Chain']',
#        '['Consulting, Information Technology, and Sales']',
#        '['Design, Art/Creative, and Information Technology']',
#        '['Finance and Sales']', '['Management', 'Manufacturing']',
#        '['Marketing and Sales']', '['Legal']',
#        '['Project Management and Engineering']', '['Education and Training']',
#        '['Management']',
#        '['Marketing, Public Relations, and Writing/Editing']', '['Marketing']',
#        '['Consulting']', '['Finance']',
#        '['Management, Distribution, and Supply Chain']',
#        '['Project Management, Consulting, and Engineering']',
#        '['Other, Information Technology, and Management']', '['Design']',
#        '['Restaurants, Leisure, Travel & Tourism, and Hospitality']',
#        '['Business Development']', '['Customer Service']',
#        '['Management, Strategy/Planning, and Consulting']',
#        '['Management, Manufacturing, and Engineering']',
#        '['Accounting/Auditing']', '['Management and Distribution']',
#        '['Sales, Business Development, and Customer Service']',
#        '['Management and Strategy/Planning']',
#        '['Sales', 'Business Development']',
#        '['Finance and Accounting/Auditing']', '['Project Management']',
#        '['Supply Chain, Customer Service, and Sales']',
#        '['Sales, Business Development, and Public Relations']',
#        '['Design, Art/Creative, and Project Management']',
#        '['Hospitality, Leisure, Travel & Tourism, and Food & Beverages']'],
#       dtype='object')

# %%
# Explore column 'level' values for errant data.
df.Level.value_counts()[df.Level.value_counts().values==1]
# Out:
# ['Engineering, Project Management, and Design']             1
# ['Purchasing', 'Supply Chain']                              1
# ['Finance, Accounting/Auditing, and Other']                 1
# ['Project Management, Marketing, and Other']                1
# ['Information Technology and Training']                     1
#                                                            ..
# ['Advertising, Marketing, and Product Management']          1
# ['Accounting/Auditing, Finance, and Administrative']        1
# ['Administrative, Business Development, and Management']    1
# ['Analyst, Information Technology, and Administrative']     1
# ['Manufacturing and Research']                              1
# Name: Level, Length: 130, dtype: int64

# %%
df.Job_Function.value_counts()[df.Job_Function.value_counts().values>5].index
# Out:
# Index(['[]', '['Management', 'Manufacturing']', '['Other']',
#        '['Sales', 'Business Development']', '['Information Technology']',
#        '['Engineering', 'Information Technology']', '['Health Care Provider']',
#        '['Human Resources']', '['Management and Manufacturing']', '['']',
#        ...
#        '['Business Development', 'Management', 'Sales']',
#        '['Purchasing, Supply Chain, and Engineering']',
#        '['Consulting, Engineering, and Project Management']',
#        '['Business Development, Customer Service, and Management']',
#        '['Other', 'Education']',
#        '['Analyst', 'Consulting', 'Strategy/Planning']',
#        '['Customer Service', 'Training', 'Human Resources']',
#        '['Customer Service and Sales']',
#        '['Administrative', 'Customer Service', 'Sales']',
#        '['Engineering, Information Technology, and Product Management']'],
#       dtype='object', length=752)

# %%
df.Industry.value_counts()[df.Industry.value_counts().values>20].index
# Out:
# Index(['[]', '['Information Technology and Services']',
#        '['Nonprofit Organization Management, Staffing and Recruiting, and Hospital & Health Care']',
#        '['Hospital & Health Care']', '['Retail']', '['Hospitality']',
#        '['Electrical/Electronic Manufacturing']',
#        '['Marketing and Advertising']', '['']', '['Construction']',
#        ...
#        '['Financial Services', 'Investment Banking', 'Investment Management']',
#        '['Farming']',
#        '['Defense & Space', 'Information Technology and Services', 'Government Relations']',
#        '['Internet', 'Food & Beverages', 'Information Technology and Services']',
#        '['Electrical/Electronic Manufacturing, Information Technology and Services, and Machinery']',
#        '['Apparel & Fashion', 'Luxury Goods & Jewelry', 'Retail']',
#        '['Construction', 'Retail', 'Hospital & Health Care']',
#        '['Insurance', 'Hospital & Health Care']',
#        '['Marketing and Advertising', 'Information Technology and Services', 'Management Consulting']',
#        '['Automotive', 'Oil & Energy', 'Human Resources']'],
#       dtype='object', length=482)

# %%
df.experience.value_counts()
# Out:
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         12431
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         11190
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         10327
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         7354
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          5596
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          4001
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3668
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         3507
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3025
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2185
# graduate                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2081
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1594
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1032
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1016
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           263
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          177
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          134
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          110
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           86
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           79
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           76
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           74
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           57
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           46
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           42
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           39
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           28
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           19
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           17
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            8
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            5
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            5
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            4
#  and Best Practices around Metrics.Masters degree in Business or Engineering.Multinational & multilingual experience is a plus.Proven Project management expertiseRelocation Eligible: Eligible for Standard RelocationJob Type: Regular                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      3
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            3
#  help in defining business and technological solutionswhich help customer design and implement new generation business processes and organization capabilities."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
#  including an aptitude for data analysis Then please Apply                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# ...
#   help in defining business and technological solutionswhich help customer design and implement new generation business processes and organization capabilities."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
#  to ensure all the work carried out is within the budget and in adherence with the plan"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
#  work in a fast-paced environment. Have a high-level attention to detail. Ability to work independently and to partner with others to promote an environment of teamwork.Education:Bachelor of Commerce or Similar or 4-year bachelor's degree in Finance and Accounting or similar majorExperience: At least 3 years' experience at the same role.Please send your CV to: "hr@deltaltd.sa"IndustryManagement ConsultingEmployment TypeFull-time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
#  and preparing proposals for new Marketing-Fund-based projects.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
#  both verbal and written."Excellent data collection and analysis skills."Strong attention to detail.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
#  debugging and documentation. You may be required to work as on-call support or in shifts."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
#  KSAA very exciting role and a very competitive package.Contact: Diala Al JandiQuote job ref: JN-032021-2180364                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
#  in an environment of continuous development. Implement and create best practices that could be shared with Finance Leadership Committee.</li> Complete ad hoc requests when required.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
#  along with the areas which costs could have been controlled. Analyzes the needs for long-term Service Contractors for TA Maintenance Services in the plant. Analyzes the invoices of all such contracts and provides reports on any discrepancy between the budgeted and actual expenditure. Based on analysis provides the trend or pattern for future expenditures/budgets. Based on analysis provides inputs for improving maintenance systems and regulates work procedure with particular thrust to effective cost control. Support Turnaround Steering committee to prepare TA maintenance budget related to additional jobs and discovery jobs Arrange for the final settlement(Business closure) of all TA orders in coordination with Hadeed Finance.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
#  please reach out to Cess Batula on: cess@emiratalent.com #jobsintech EmiraTalent                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
#  OSCE is a plus.Good understanding of Incident Response (Blue Team) methodologies. Certifications such as GNFA is a plus.Good understanding of Cloud Security and Network Architectures. Certifications such as AWS Certified Security Specialty (SCS-C01) is a plus.Good understanding of Security Processes and methodologies. Certifications such as CISSP is a plus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Name: experience, dtype: int64

# %%
df.columns
# Out:
# Index(['position_id', 'Position', 'Company', 'Location', 'Date', 'Level',
#        'Job_Function', 'Industry', 'Description', 'Link', 'linkedin_id',
#        'company_linkedin_url', 'experience'],
#       dtype='object')

# %% [markdown]
# <a id='Assesment Report'></a>
# ### Final Assesment Report
#
# - Columns 'Unnamed: 0', and 'position_id' has no valuable data(less important).
#
# - Columns names have a capital letters.
#
# - Columns 'Position', 'Job_Function' has similar content.
#
# - Column 'Company' contain location data.
#
# - Column 'Location' contain Date data
#
# - Column 'Date' is object type. (the time period may be short to get a good insights)
#
# - Column 'Level' has a lot of data differnt from level class.
#
# - Column experience is object type and has errant data.
#
# - All columns have nan values.

# %% [markdown]
# ## Data Cleaning
#
# befor cleaning copying DataFrames in pandas is done using .copy method

# %%
df_clean = df.copy()

# %% [markdown]
# ### Columns 'Unnamed: 0', and 'position_id' has no valuable data(less important).

# %%
# drop columns that not helpful for my analysis
df_clean.drop(["position_id", "Description", "Link",
               "linkedin_id", "company_linkedin_url"], axis=1, errors="ignore" , inplace = True)

# %%
df_clean.head(1)
# Out:
#                             Position     Company              Location  \
# 0  Head of Branding Governance Unit   Riyad Bank  Riyadh, Saudi Arabia
#
#                   Date             Level                 Job_Function  \
# 0  2020-01-06 00:00:00  Mid-Senior level  ['Marketing', 'Management']
#
#       Industry experience
# 0  ['Banking']        NaN

# %% [markdown]
# ### Columns names have a capital letters.

# %%
df_clean.rename(columns=lambda x : x.lower(),inplace=True)

# %%
df_clean.head(1)
# Out:
#                             position     company              location  \
# 0  Head of Branding Governance Unit   Riyad Bank  Riyadh, Saudi Arabia
#
#                   date             level                 job_function  \
# 0  2020-01-06 00:00:00  Mid-Senior level  ['Marketing', 'Management']
#
#       industry experience
# 0  ['Banking']        NaN

# %% [markdown]
# ## Columns 'Position', 'Job_Function' has similar content.

# %%
# creating a new column named 'department'
df_clean['department'] = ''
# merging the two columns 'position' and 'job_function' into a new column 'position_job_function'.
df_clean['position_job_function'] = df_clean['position']+' '+df_clean['job_function']
# exploring the dataframe.
df_clean.head(5)
# Out:
#                             position                        company  \
# 0  Head of Branding Governance Unit                      Riyad Bank
# 1                Document Controller      Confidential,Confidential
# 2     Employee Engagement Specialist                        PepsiCo
# 3        Strategic Workforce Analyst  Saudi Air Navigation Services
# 4      Account Manager, GPS – Riyadh                             EY
#
#                location                 date             level  \
# 0  Riyadh, Saudi Arabia  2020-01-06 00:00:00  Mid-Senior level
# 1  Riyadh, Saudi Arabia  2020-01-06 00:00:00         Associate
# 2  Riyadh, Saudi Arabia  2020-01-06 00:00:00  Mid-Senior level
# 3  Jeddah, Saudi Arabia  2020-01-06 00:00:00  Mid-Senior level
# 4  Riyadh, Saudi Arabia  2020-01-06 00:00:00    Not Applicable
#
#                         job_function                                industry  \
# 0        ['Marketing', 'Management']                             ['Banking']
# 1                               ['']           ['Government Administration']
# 2                ['Human Resources']  ['Consumer Goods', 'Food & Beverages']
# 3                               ['']                ['Aviation & Aerospace']
# 4  ['Sales', 'Business Development']    ['Accounting', 'Financial Services']
#
#   experience department                              position_job_function
# 0        NaN             Head of Branding Governance Unit  ['Marketing'...
# 1          3                                      Document Controller ['']
# 2          1             Employee Engagement Specialist ['Human Resourc...
# 3        NaN                              Strategic Workforce Analyst ['']
# 4          7             Account Manager, GPS – Riyadh ['Sales', 'Busin...

# %%
df_clean.position_job_function.value_counts()[df_clean.position_job_function.value_counts().values>50].index
# Out:
# Index(['Care Assistant ['Other']',
#        'Store Associate ['Sales', 'Business Development']',
#        'Store Associate ['']', 'Accountant ['Accounting/Auditing', 'Finance']',
#        'Project Manager ['Project Management', 'Information Technology']',
#        'Accountant []',
#        'Graphic Designer ['Design', 'Art/Creative', 'Information Technology']',
#        'Graphic Designer []',
#        'Sales Manager ['Sales', 'Business Development']', 'Salesman ['Sales']',
#        'Business Development Manager ['Sales', 'Business Development']',
#        'Sales Executive ['Sales', 'Business Development']',
#        'Account Manager ['Sales', 'Business Development']',
#        'Marketing Manager ['Marketing', 'Sales']',
#        'Senior Accountant ['Accounting/Auditing', 'Finance']',
#        'Document Controller ['Administrative']',
#        'Store Associate ['Sales and Business Development']',
#        'Human Resources Manager ['Human Resources']',
#        'Marketing Specialist ['Marketing', 'Sales']',
#        'Sales Engineer ['Sales', 'Business Development']',
#        'Sales Specialist ['Sales', 'Business Development']',
#        'Digital Marketing Specialist ['Marketing', 'Sales']',
#        'National Sales Manager ['Sales', 'Business Development']',
#        'Field Care Supervisor ['Management and Manufacturing']',
#        'Business Development Manager []',
#        'Senior React Developer – Full-time, Remote ['Engineering', 'Information Technology']',
#        'Sales Executive []', 'Marketing Specialist []',
#        'Executive Secretary ['Administrative']',
#        'Finance Manager ['Finance', 'Sales']',
#        'Executive Assistant ['Administrative']',
#        'Operations Manager ['Management', 'Manufacturing']',
#        'Administrative Assistant ['Administrative']',
#        'Sales Associate ['Sales', 'Business Development']', 'Sales Manager []',
#        'Cashier - RTL ['Sales', 'Business Development']',
#        'Registered Nurse ['Health Care Provider']',
#        'Warehouse Team Member ['Management', 'Manufacturing']',
#        'Barista ['Management', 'Manufacturing']', 'Barista []',
#        'Amazon Warehouse Associate - Immediate Hire! ['Management', 'Manufacturing']',
#        'Digital Marketing Specialist []',
#        'Cashier ['Sales', 'Business Development']',
#        'Mechanical Engineer ['Engineering', 'Information Technology']',
#        'Project Manager []', 'Marketing Manager []',
#        'Assistant Store Manager ['Sales', 'Business Development']',
#        'Store Manager ['Sales', 'Business Development']',
#        'National Manager Project Logistics ['Project Management', 'Information Technology']',
#        'Electrical Engineer ['Engineering', 'Information Technology']',
#        'Care Coordinator ['Other']', 'Sales Representative []',
#        'Senior Accountant []', 'Human Resources Specialist []',
#        'Nurse ['Health Care Provider']',
#        'Finance Controller ['Accounting/Auditing and Finance']',
#        'Project Manager ['Project Management and Information Technology']',
#        'Receptionist []', 'Sales Engineer []',
#        'Amazon Picker Packer - Immediate Hire (Full-Time) ['Management', 'Manufacturing']',
#        'Business Development Representative ['Sales', 'Business Development']',
#        'Business Development Specialist ['Business Development', 'Sales']',
#        'Interior Designer ['Design', 'Art/Creative', 'Information Technology']',
#        'Sales Specialist []', 'Sales Associate ['']',
#        'Construction Manager ['Management', 'Manufacturing']',
#        'Secretary ['Administrative']',
#        'Allied Healthcare ['Nonprofit Organization Management, Staffing and Recruiting, and Hospital & Health Care']',
#        'Field Service Engineer ['Information Technology']',
#        'Sales Representative ['Sales', 'Business Development']',
#        'Preseller ['Sales']',
#        'Amazon Picker/Packer - Earn up to $18.30/hr! ['Management', 'Manufacturing']',
#        'Human Resources Specialist ['Human Resources']',
#        'Project Control Manager ['Management', 'Manufacturing']',
#        'Procurement Manager ['Purchasing', 'Supply Chain']',
#        'Pastry Chef ['Management', 'Manufacturing']',
#        'Sea Logistics Sales ['Management', 'Manufacturing']',
#        'Project Director ['Management', 'Manufacturing']',
#        'Amazon Order Picker/Packer - Full-time and Part-time ['Management', 'Manufacturing']',
#        'Commercial Manager ['Sales', 'Management']',
#        'Waiter ['Management', 'Manufacturing']',
#        'Project Manager ['Project Management']', 'Executive Secretary []',
#        'Customer Care Location Manager ['Customer Service and Information Technology']',
#        'Restaurant Manager ['Management', 'Manufacturing']',
#        'Contracts Manager ['Management', 'Manufacturing']',
#        'Talent Acquisition Specialist ['Human Resources']',
#        'Electrical Inspector Pipeline Projects-Rabigh ['Management', 'Manufacturing']'],
#       dtype='object')

# %%
df_clean.position_job_function.isnull().sum()
# Out:
# 2445

# %%
df_clean['position_job_function'].fillna(" d ")
# Out:
# 0         Head of Branding Governance Unit  ['Marketing'...
# 1                                  Document Controller ['']
# 2         Employee Engagement Specialist ['Human Resourc...
# 3                          Strategic Workforce Analyst ['']
# 4         Account Manager, GPS – Riyadh ['Sales', 'Busin...
#                                 ...
# 125642                                        Accountant []
# 125643          Enterprise Resources Planning Specialist []
# 125644    HR Development Specialist ( Tamheer ) أخصائي ت...
# 125645    Customer Experience Associate ['Customer Servi...
# 125646                     Program Officer, Saudi Arabia []
# Name: position_job_function, Length: 125647, dtype: object

# %%
# using regex to extract the multiple departments.
for index, row in df_clean.iterrows():  
    string = str(row['position_job_function'])
    pattern = re.search('Care|Medical|Nurse|Health',string, re.I)
    
    if pattern:
        df_clean.loc[index,'department'] = 'health care'
       
    
    else:
        pattern = re.search('Account|Finance|Cashier|محاسب',string, re.I)
        if pattern:
            df_clean.loc[index,'department'] = 'finance'
      
        else:
            pattern = re.search('Business|Admin|Secretary',string, re.I)
            if pattern:
                df_clean.loc[index,'department'] = 'adminstration'
        
            else:
                pattern = re.search('Sales|Marketing|Market',string, re.I)
                if pattern:
                    df_clean.loc[index,'department'] = 'sales'
        
                else:
                    pattern = re.search('Human|Human Resources|Recruitment',string, re.I)
                    if pattern:
                        df_clean.loc[index,'department'] = 'human resources' 
      
                    else:
                        pattern = re.search('Logistics|Store|Supply|Warehouse|Purchasing|Goods|Distribution',string, re.I)
                        if pattern:
                            df_clean.loc[index,'department'] = 'logistics'
              
                        else:
                            pattern = re.search('Training|quality|Consulting|Warehouse|Purchasing|Goods|Distribution',string, re.I)
                            if pattern:
                                df_clean.loc[index,'department'] = 'training and quality' 
                                
                            else:
                                pattern = re.search('Public Relations|Social|relations',string, re.I)
                                if pattern:
                                    df_clean.loc[index,'department'] = 'public relations' 
       
                                else:
                                    pattern = re.search('Planning|Product|Manufactur|Design|Specialist',string, re.I)
                                    if pattern:
                                        df_clean.loc[index,'department'] = 'engineering'
              
                                    else:
                                        pattern = re.search('Project|Engineer|Architect|Software|Technology',string, re.I)
                                        if pattern:
                                            df_clean.loc[index,'department'] = 'Information Technology'
                                        else:
                                              df_clean.loc[index,'department'] = 'other'

# %%
df_clean.department.value_counts().index
# Out:
# Index(['Information Technology', 'engineering', 'adminstration', 'other',
#        'finance', 'sales', 'health care', 'logistics', 'training and quality',
#        'human resources', 'public relations'],
#       dtype='object')

# %%
#drop the two columns 'position' ,  'job_function', 'position_job_function'.
df_clean.drop(columns =['position' ,  'job_function', 'position_job_function' ] , inplace = True)

# %% [markdown]
# ### Column 'Company' contain location data.

# %%
#using regex create location dict with shifted data. 
loc_dict = {}
for index, row in df_clean.iterrows():  
    string = str(row['company'])
    pattern = re.search('(, Saudi Arabia)',string, re.I)
    if pattern:
        loc_dict[index] = pattern.string.split(',')[-2].strip()

# %%
#iterate location dict to put the data in the location column. and clear the crossponding cell in company column.
for k,v in loc_dict.items():
    df_clean.iloc[int(k),1]=v
    df_clean.iloc[int(k),0]=""

# %%
df_clean['company'].value_counts()
# Out:
# Allied Healthcare                  2748
# Confidential                       2610
# Parsons Corporation                2546
# Landmark Arabia                    1925
# Crossover for Work                 1813
#                                    ...
# United Support Company                1
# Agencia Pública de Empleo SENA        1
# Crawford & Company                    1
# Scadea                                1
# Charles Hunter Associates             1
# Name: company, Length: 16133, dtype: int64

# %% [markdown]
# ### Column 'Location' contain Date data

# %%
#using regex create date dict with shifted data. and correct the location values.
date_dict = {}
loc2_dict = {}
for index, row in df_clean.iterrows():  
    string = str(row['location'])
    pattern = re.search('(\d{4})-(\d{2})-(\d{2}) (\d{2}):(\d{2}):(\d{2})',string, re.I)
    if pattern:
        date_dict[index] = pattern.string
    else:
        try:
            loc2_dict[index] = string.split(',')[-2].strip()
        except:
            loc2_dict[index] = string.split(',')[-1].strip()

# %%
#iterate location dict to put the data in the location column. and clear the crossponding cell in company column.
for k,v in loc2_dict.items():
    df_clean.iloc[int(k),1]=v

#iterate date dict to put the data in the date column. and clear the crossponding cell in location column.
for k,v in date_dict.items():
    df_clean.iloc[int(k),2]=v
    df_clean.iloc[int(k),1]=""

# %%
#test the location valuesafter correction
df_clean.location.value_counts()[df_clean.location.value_counts().values>4].index
# Out:
# Index(['Riyadh', 'Makkah', 'Eastern', 'Saudi Arabia', 'Al Madinah',
#        'Makkah Region', 'nan', 'Riyadh Region', 'Eastern Region', 'Tabuk',
#        'Jizan', 'Jeddah', ''Asir', 'Al Qasim', 'Ha'il', 'Al Jubayl', 'Al Jawf',
#        'Dammam', 'Khobar', 'Jazan Region', '', 'Dhahran', 'Tabuk Region',
#        'Najran', 'Madinah', 'Northern Borders Region', 'Qaseem',
#        'Northern Frontier', 'Al-Qassim Region', 'Asir Region',
#        'Madinah Region', 'Al Bahah', 'Al Mubarraz', 'Yanbu', 'Banban',
#        'Abqaiq', 'As Sulayyil', 'Jubail', '‘Unayzah', 'Ḩafar al Baţin',
#        'Najran Region', 'Ḑubā', 'Al-Bahah Region', 'United Arab Emirates',
#        'Rabigh', 'Hail Region', 'Tabouk', 'Ahsa', 'Burgundy-Franche-Comte',
#        'Ar Ramādīyāt', 'Ra’s al Khafji', 'Taif', 'Al-Jawf Region',
#        'Ad Dawādimī', 'India', 'Baha', 'King Khalid Military City', 'Wales',
#        'Hail', 'Associate', 'As Sulimaniyah', 'Dubai', 'Entry level'],
#       dtype='object')

# %%
df_clean
# Out:
#                               company location                 date  \
# 0                          Riyad Bank   Riyadh  2020-01-06 00:00:00
# 1           Confidential,Confidential   Riyadh  2020-01-06 00:00:00
# 2                             PepsiCo   Riyadh  2020-01-06 00:00:00
# 3       Saudi Air Navigation Services   Jeddah  2020-01-06 00:00:00
# 4                                  EY   Riyadh  2020-01-06 00:00:00
# ...                               ...      ...                  ...
# 125642                         Unkown   Riyadh  2021-11-12 00:00:00
# 125643                     Xbress.com   Riyadh  2021-11-12 00:00:00
# 125644     SFDA - هيئة الغذاء والدواء   Riyadh  2021-11-11 00:00:00
# 125645                      Calo Inc.  Eastern  2021-09-19 00:00:00
# 125646                      Flat6Labs   Riyadh  2021-11-11 00:00:00
#
#                    level                                           industry  \
# 0       Mid-Senior level                                        ['Banking']
# 1              Associate                      ['Government Administration']
# 2       Mid-Senior level             ['Consumer Goods', 'Food & Beverages']
# 3       Mid-Senior level                           ['Aviation & Aerospace']
# 4         Not Applicable               ['Accounting', 'Financial Services']
# ...                  ...                                                ...
# 125642               NaN                                                 []
# 125643               NaN                                                 []
# 125644       Entry level                      ['Government Administration']
# 125645       Entry level  ['Restaurants, Food and Beverage Services, and...
# 125646               NaN                                                 []
#
#        experience              department
# 0             NaN                   sales
# 1               3                   other
# 2               1         human resources
# 3             NaN                   other
# 4               7                 finance
# ...           ...                     ...
# 125642        NaN                 finance
# 125643          3             engineering
# 125644        NaN         human resources
# 125645          1  Information Technology
# 125646          1                   other
#
# [125647 rows x 7 columns]

# %% [markdown]
# ### Column 'Date' is object type. (the time period may be short to get a good insights)

# %%
df_clean['date']= pd.to_datetime(df_clean['date'] , errors='coerce', format='%Y-%m-%d')

# %%
df_clean.date
# Out:
# 0        2020-01-06
# 1        2020-01-06
# 2        2020-01-06
# 3        2020-01-06
# 4        2020-01-06
#             ...
# 125642   2021-11-12
# 125643   2021-11-12
# 125644   2021-11-11
# 125645   2021-09-19
# 125646   2021-11-11
# Name: date, Length: 125647, dtype: datetime64[ns]

# %%
df_clean['month']=df_clean['date'].dt.month_name()
df_clean
# Out:
#                               company location       date             level  \
# 0                          Riyad Bank   Riyadh 2020-01-06  Mid-Senior level
# 1           Confidential,Confidential   Riyadh 2020-01-06         Associate
# 2                             PepsiCo   Riyadh 2020-01-06  Mid-Senior level
# 3       Saudi Air Navigation Services   Jeddah 2020-01-06  Mid-Senior level
# 4                                  EY   Riyadh 2020-01-06    Not Applicable
# ...                               ...      ...        ...               ...
# 125642                         Unkown   Riyadh 2021-11-12               NaN
# 125643                     Xbress.com   Riyadh 2021-11-12               NaN
# 125644     SFDA - هيئة الغذاء والدواء   Riyadh 2021-11-11       Entry level
# 125645                      Calo Inc.  Eastern 2021-09-19       Entry level
# 125646                      Flat6Labs   Riyadh 2021-11-11               NaN
#
#                                                  industry experience  \
# 0                                             ['Banking']        NaN
# 1                           ['Government Administration']          3
# 2                  ['Consumer Goods', 'Food & Beverages']          1
# 3                                ['Aviation & Aerospace']        NaN
# 4                    ['Accounting', 'Financial Services']          7
# ...                                                   ...        ...
# 125642                                                 []        NaN
# 125643                                                 []          3
# 125644                      ['Government Administration']        NaN
# 125645  ['Restaurants, Food and Beverage Services, and...          1
# 125646                                                 []          1
#
#                     department      month
# 0                        sales    January
# 1                        other    January
# 2              human resources    January
# 3                        other    January
# 4                      finance    January
# ...                        ...        ...
# 125642                 finance   November
# 125643             engineering   November
# 125644         human resources   November
# 125645  Information Technology  September
# 125646                   other   November
#
# [125647 rows x 8 columns]

# %% [markdown]
# ### Column experience is object type and has errant data.

# %%
df_clean['experience']= df_clean['experience'].str.extract('(\d+)')
df_clean= df_clean.drop(df_clean[df_clean['experience']=='032021'].index)
df_clean['experience'].replace('01','1', inplace=True)

# %%
df_clean.experience.value_counts()
# Out:
# 5     12431
# 3     11190
# 2     10328
# 10     7355
# 1      5597
# 4      4002
# 8      3668
# 15     3507
# 7      3025
# 6      2185
# 12     1594
# 0      1032
# 20     1016
# 9       263
# 14      177
# 18      134
# 30      110
# 24       86
# 13       79
# 25       76
# 21       74
# 11       57
# 16       46
# 22       42
# 35       39
# 17       28
# 26       19
# 23       17
# 19        8
# 28        5
# 27        5
# 31        4
# 32        3
# 29        1
# Name: experience, dtype: int64

# %%
df_clean['experience']= df_clean['experience'].fillna(0)
df_clean['experience']= df_clean['experience'].astype(int)
df_clean.experience.value_counts()
# Out:
# 0     58475
# 5     12431
# 3     11190
# 2     10328
# 10     7355
# 1      5597
# 4      4002
# 8      3668
# 15     3507
# 7      3025
# 6      2185
# 12     1594
# 20     1016
# 9       263
# 14      177
# 18      134
# 30      110
# 24       86
# 13       79
# 25       76
# 21       74
# 11       57
# 16       46
# 22       42
# 35       39
# 17       28
# 26       19
# 23       17
# 19        8
# 27        5
# 28        5
# 31        4
# 32        3
# 29        1
# Name: experience, dtype: int64

# %% [markdown]
# ### Column 'Level' has a lot of data differnt from level class.

# %%
df_clean.groupby('level').experience.mean()
# Out:
# level
# \n\n\n        Experience \n      \n\n        Show more\n\n        \n\n\n        Show less\n\n        \n\n\n    0.000000
# 2021-09-06 00:00:00                                                                                            0.000000
# Associate                                                                                                      3.395087
# Director                                                                                                       5.624619
# Entry level                                                                                                    1.940081
#                                                                                                                  ...
# ['Supply Chain, Distribution, and Administrative']                                                             0.000000
# ['Training and Other']                                                                                         0.000000
# ['Utilities']                                                                                                  0.000000
# ['Writing/Editing']                                                                                            0.000000
# []                                                                                                             0.000000
# Name: experience, Length: 189, dtype: float64

# %%
#create level list
level_list = [ 'Internship', 'Entry level', 'Mid-Senior level', 'Associate', 'Director', 'Executive']
for index, row in df_clean.iterrows():
    if row['level'] not in level_list:
        if df_clean.loc[index,'experience']<1:
            df_clean.loc[index,'level'] = 'Internship'
        elif df_clean.loc[index,'experience']<=2:
            df_clean.loc[index,'level'] = 'Entry level'
        if df_clean.loc[index,'experience']<=3:
            df_clean.loc[index,'level'] = 'Associate'
        if df_clean.loc[index,'experience']<=4:
            df_clean.loc[index,'level'] = 'Executive'
        if df_clean.loc[index,'experience']<=5:
            df_clean.loc[index,'level'] = 'Mid-Senior level'
        if df_clean.loc[index,'experience']>5:
            df_clean.loc[index,'level'] = 'Director'           
    else:
        df_clean.loc[index,'level'] = row['level']

# %%
df_clean.level.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### All columns have nan values.

# %%
fig, ax = plt.subplots(figsize=(9,6))
sb.heatmap(df_clean.isnull(), cbar=False, cmap="YlGnBu_r")
plt.show()

# %%
#drob null values by rows
df_clean.dropna(subset=['company'],inplace=True)

# %%
fig, ax = plt.subplots(figsize=(9,6))
sb.heatmap(df_clean.isnull(), cbar=False, cmap="YlGnBu_r")
plt.show()

# %%
df_clean.head(40)
# Out:
#                                               company      location  \
# 0                                          Riyad Bank        Riyadh
# 1                           Confidential,Confidential        Riyadh
# 2                                             PepsiCo        Riyadh
# 3                       Saudi Air Navigation Services        Jeddah
# 4                                                  EY        Riyadh
# 5                                    Geidea Solutions        Riyadh
# 6                                             Philips        Riyadh
# 7   تطوير تقنيات التعليم | Tatweer Educational Tec...        Riyadh
# 8                              WSP in the Middle East        Riyadh
# 9                                          SC Johnson        Jeddah
# 10                              Aventus Global Talent  Saudi Arabia
# 11                           Digby Morris Recruitment        Jeddah
# 12                                    Takamol Holding        Riyadh
# 13                                           Unilever        Dammam
# 14                                            SEPHORA        Riyadh
# 15  AVK Saudi Valve Manufacturing Co. Ltd. (AVK SV...        Jeddah
# 16                                            Aggreko        Jeddah
# 17                               Logicom Distribution        Riyadh
# 18                                        Halliburton        Khobar
# 19                             Hassan Jameel for Cars        Dammam
# 20          AL-KHALEEJ COMPUTERS & ELECTRONIC SYSTEMS        Riyadh
# 21                                        Elm Company        Riyadh
# 22                                             Careem        Jeddah
# 23  الاتحاد السعودي للأمن السيبراني والبرمجة والدر...        Riyadh
# 24                        Priority Project Office-PPO        Riyadh
# 25                                       Petro Rabigh        Rabigh
# 26                                     Khatib & Alami        Jeddah
# 27                                             Kitopi        Jeddah
# 28             Al Fayhaa Construction and Contracting        Riyadh
# 29                                  Abunayyan Holding        Khobar
# 30                                                AHC        Riyadh
# 31                                              Klook        Riyadh
# 32                                       Confidential        Riyadh
# 33                             Lean Business Services        Riyadh
# 34                                              AECOM        Riyadh
# 35                                  Almarai - المراعي        Riyadh
# 36                                      almajal Group        Jeddah
# 37                              Courtyard by Marriott        Riyadh
# 38                      Leader Investment Group - LIG        Riyadh
# 39                          HungerStation | هنقرستيشن        Riyadh
#
#          date             level  \
# 0  2020-01-06  Mid-Senior level
# 1  2020-01-06         Associate
# 2  2020-01-06  Mid-Senior level
# 3  2020-01-06  Mid-Senior level
# 4  2020-01-06          Director
# 5  2020-01-06          Director
# 6  2020-01-06  Mid-Senior level
# 7  2020-01-06  Mid-Senior level
# 8  2020-01-06         Associate
# 9  2020-01-06  Mid-Senior level
# 10 2020-01-06  Mid-Senior level
# 11 2020-01-06  Mid-Senior level
# 12 2020-01-06         Associate
# 13 2020-01-06  Mid-Senior level
# 14 2020-01-06  Mid-Senior level
# 15 2020-01-06  Mid-Senior level
# 16 2020-01-06  Mid-Senior level
# 17 2020-01-06         Associate
# 18 2020-01-06       Entry level
# 19 2020-01-06  Mid-Senior level
# 20 2020-01-06         Associate
# 21 2020-01-06         Associate
# 22 2020-01-06       Entry level
# 23 2020-01-06          Director
# 24 2020-01-06  Mid-Senior level
# 25 2020-01-06  Mid-Senior level
# 26 2020-01-06         Associate
# 27 2020-01-06         Associate
# 28 2020-01-06  Mid-Senior level
# 29 2020-01-06         Associate
# 30 2020-01-06  Mid-Senior level
# 31 2020-01-06  Mid-Senior level
# 32 2020-01-06  Mid-Senior level
# 33 2020-01-06  Mid-Senior level
# 34 2020-01-06  Mid-Senior level
# 35 2020-01-06          Director
# 36 2020-01-06  Mid-Senior level
# 37 2020-01-06       Entry level
# 38 2020-01-06  Mid-Senior level
# 39 2020-01-06  Mid-Senior level
#
#                                              industry  experience  \
# 0                                         ['Banking']           0
# 1                       ['Government Administration']           3
# 2              ['Consumer Goods', 'Food & Beverages']           1
# 3                            ['Aviation & Aerospace']           0
# 4                ['Accounting', 'Financial Services']           7
# 5   ['Information Technology and Services', 'Finan...           0
# 6                                                ['']           0
# 7             ['Information Technology and Services']           5
# 8                                    ['Construction']           5
# 9                                                ['']           0
# 10                  ['Financial Services', 'Banking']           5
# 11  ['Construction', 'Civil Engineering', 'Logisti...           0
# 12                          ['Management Consulting']           2
# 13                                               ['']           0
# 14                                               ['']           0
# 15           ['Mechanical or Industrial Engineering']           0
# 16  ['Marketing and Advertising', 'Mechanical or I...           1
# 17            ['Information Technology and Services']           0
# 18  ['Construction', 'Information Technology and S...           2
# 19                                     ['Automotive']           0
# 20  ['Information Technology and Services', 'Banki...           0
# 21            ['Information Technology and Services']           8
# 22  ['Internet', 'Information Technology and Servi...           0
# 23              ['Nonprofit Organization Management']           5
# 24                                               ['']           0
# 25                                   ['Oil & Energy']           0
# 26    ['Design', 'Construction', 'Civil Engineering']           0
# 27  ['Marketing and Advertising', 'Information Tec...           0
# 28                                               ['']           0
# 29          ['Construction', 'Industrial Automation']           2
# 30                         ['Hospital & Health Care']           0
# 31                                               ['']           0
# 32                           ['Consumer Electronics']           0
# 33            ['Information Technology and Services']           0
# 34  ['Architecture & Planning', 'Civil Engineering...          12
# 35            ['Food Production', 'Food & Beverages']           0
# 36                 ['Facilities Services', 'Banking']           0
# 37  ['Restaurants', 'Staffing and Recruiting', 'Ho...           0
# 38                                               ['']           0
# 39                                       ['Internet']           1
#
#                 department    month
# 0                    sales  January
# 1                    other  January
# 2          human resources  January
# 3                    other  January
# 4                  finance  January
# 5                    sales  January
# 6                    other  January
# 7            adminstration  January
# 8                  finance  January
# 9                    sales  January
# 10         human resources  January
# 11               logistics  January
# 12    training and quality  January
# 13               logistics  January
# 14                   other  January
# 15                   sales  January
# 16             engineering  January
# 17           adminstration  January
# 18           adminstration  January
# 19                   sales  January
# 20           adminstration  January
# 21  Information Technology  January
# 22             engineering  January
# 23           adminstration  January
# 24           adminstration  January
# 25        public relations  January
# 26  Information Technology  January
# 27               logistics  January
# 28                   other  January
# 29                   other  January
# 30             engineering  January
# 31                   sales  January
# 32                   other  January
# 33           adminstration  January
# 34  Information Technology  January
# 35               logistics  January
# 36                   other  January
# 37         human resources  January
# 38             engineering  January
# 39           adminstration  January

# %% [markdown]
# ### Column Industry has errant data.

# %%
# using regex to extract the multiple departments.
for index, row in df_clean.iterrows():  
    string = str(row['industry'])
    pattern = re.search('Nonprofit|Non-profit',string, re.I)
    
    if pattern:
        df_clean.loc[index,'industry'] = 'Nonprofit Organization'
    else:
        pattern = re.search('Internet|Computer Software|IT Services|Computer Games|Network|Computer',string, re.I)
        if pattern:
            df_clean.loc[index,'industry'] = 'IT Services'
        else:
            pattern = re.search('Retail|quality|Goods|Packaging|Commercial|Logistics | Aviation | Aerospace |Market|Advertising|Airlines',string, re.I)
            if pattern:
                df_clean.loc[index,'industry'] = 'Retail'

            else:
                pattern = re.search('Utilities|Hospitality|Restaurants|Fitness|Travel|Luxury|Government|Education|Transportation|Communications|Environmental',string, re.I)
                if pattern:
                    df_clean.loc[index,'industry'] = 'Utilities'
        
                else:
                    pattern = re.search('manufacturing|Chemicals|Automotive|Warehouse|Purchasing|Goods|Distribution|Construction|Oil & Energy|Construction|Civil Engineering|Electrical|Mechanical|Planning|Nanotechnology|Production|Biotechnology',string, re.I)
                    if pattern:
                        df_clean.loc[index,'industry'] = 'Industrial'
                    else:
                        pattern = re.search('Financial Services|Insurance|Banking|Investment',string, re.I)
                        if pattern:
                            df_clean.loc[index,'industry'] = 'Finance'

                        else:
                            pattern = re.search('Medical|Pharmaceuticals',string, re.I)
                            if pattern:
                                df_clean.loc[index,'industry'] = 'Medical' 

                            else:
                                df_clean.loc[index,'industry'] = 'other'

# %%
df_clean.industry.value_counts()
# Out:
# other                     40091
# Industrial                21756
# Retail                    18251
# IT Services               15173
# Utilities                 14514
# Finance                    7259
# Nonprofit Organization     3801
# Medical                    2348
# Name: industry, dtype: int64

# %%
df_clean.head()
# Out:
#                          company location       date             level  \
# 0                     Riyad Bank   Riyadh 2020-01-06  Mid-Senior level
# 1      Confidential,Confidential   Riyadh 2020-01-06         Associate
# 2                        PepsiCo   Riyadh 2020-01-06  Mid-Senior level
# 3  Saudi Air Navigation Services   Jeddah 2020-01-06  Mid-Senior level
# 4                             EY   Riyadh 2020-01-06          Director
#
#     industry  experience       department    month
# 0    Finance           0            sales  January
# 1  Utilities           3            other  January
# 2     Retail           1  human resources  January
# 3      other           0            other  January
# 4    Finance           7          finance  January

# %% [markdown]
#  # Store Data

# %%
if not os.path.isfile('dataset_cleaned.csv'):
    df_clean.to_csv('dataset_cleaned.csv', index = False)

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# >  Now I trimmed and cleaned data, I am ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that I posed in the Introduction section.

# %%
#load the cleaned dataset
explor = pd.read_csv('dataset_cleaned.csv')
explor.head(3)
# Out:
#                      company location                 date             level  \
# 0                 Riyad Bank   Riyadh  2020-01-06 00:00:00  Mid-Senior level
# 1  Confidential,Confidential   Riyadh  2020-01-06 00:00:00         Associate
# 2                    PepsiCo   Riyadh  2020-01-06 00:00:00  Mid-Senior level
#
#     industry  experience       department    month
# 0    Finance           0            sales  January
# 1  Utilities           3            other  January
# 2     Retail           1  human resources  January

# %% [markdown]
# ## Univariate Exploration
# #### In this section, we are going to investigate distributions of individual variables. and checking for unusual points or outliers.

# %%
plt.figure(figsize = [20,8])
base_color =sb.color_palette()[0]
data = explor.level.value_counts()
plt.bar(x = data.index,height= data.values ,color=  base_color, width = .3)
plt.tick_params(labelsize = 20)
plt.xlabel('Job level', fontsize=30)
plt.ylabel('Number of job post', fontsize=30, rotation = 'vertical')
plt.title('Number of job post for each job level', fontsize = 30);

# %%
plt.figure(figsize = [20,8])
base_color =sb.color_palette()[0]
data = explor.industry.value_counts()
plt.bar(x = data.index,height= data.values ,color=  base_color, width = .3)
plt.tick_params(labelsize = 20)
plt.xlabel('Industry', fontsize=30)
plt.ylabel('Number of job post', fontsize=30, rotation = 'vertical')
plt.title('Number of job post for each industry', fontsize = 30);

# %% [markdown]
# ## Research Question 1 (What is the direction of the labor market?)

# %%
plt.figure(figsize = [20,8])
base_color =sb.color_palette()[0]
data = explor.department.value_counts()
plt.bar(x = data.index,height= data.values ,color=  base_color, width = .6)
plt.tick_params(labelsize = 20,rotation=70)
plt.xlabel('Department', fontsize=30)
plt.ylabel('Number of job post', fontsize=30, rotation = 'vertical')
plt.title('Number of job post for each Department', fontsize = 30);

# %% [markdown]
# ## Research Question 2 (What is the peak month of job posting?.)

# %%
plt.figure(figsize = [20,8])
base_color =sb.color_palette()[0]
order = ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December']
sb.countplot(data = explor, x = 'month', color=  base_color, order = order)
plt.tick_params(labelsize = 20)
plt.xlabel('Months', fontsize=20)
plt.ylabel('Number of job posts', fontsize=20, rotation = 'vertical')
plt.title('Peak month of job posting \n' , fontsize = 40);

# %%
top10_location= list(explor.location.value_counts()[:10].index)

# %%
plt.figure(figsize = [20,6])
base_color =sb.color_palette()[0]
sb.countplot(data = explor[explor.location.isin(top10_location)], y = 'location', color=  base_color, order = top10_location)

job_counts = explor.location.value_counts()
for i in range (10):           #loop to write text on each bar
    count = job_counts[i]
    text = '{}'.format(job_counts.index[i])
    plt.text(count, i, text, va = 'center',fontsize=22, color = 'black')
    
    
plt.tick_params(axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.xlabel('Counts', fontsize=30)
plt.ylabel('', fontsize=30)
plt.yticks([])
plt.title('Top 10 location', fontsize = 30);

# %%
top10_company= list(explor.company.value_counts()[:10].index)
top10_company
# Out:
# ['Allied Healthcare',
#  'Confidential',
#  'Parsons Corporation',
#  'Landmark Arabia',
#  'Crossover for Work',
#  'Amazon',
#  'AFRY',
#  'PwC Middle East',
#  'PepsiCo',
#  'AllRetailJobs.com']

# %%
plt.figure(figsize = [20,10])
base_color =sb.color_palette()[0]
sb.countplot(data = explor[explor.company.isin(top10_company)], y = 'company', color=  base_color, order = top10_company)

job_counts = explor.company.value_counts()
for i in range (10):           #loop to write text on each bar
    count = job_counts[i]
    text = '{}'.format(job_counts.index[i])
    plt.text(count, i, text, va = 'center',fontsize=22, color = 'black')
    
    
plt.tick_params(axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.xlabel('Count', fontsize=30)
plt.ylabel('', fontsize=30)
plt.yticks([])
plt.title('Top 10 company', fontsize = 30);

# %%
explor
# Out:
#                               company location       date             level  \
# 0                          Riyad Bank   Riyadh 2020-01-06  Mid-Senior level
# 1           Confidential,Confidential   Riyadh 2020-01-06         Associate
# 2                             PepsiCo   Riyadh 2020-01-06  Mid-Senior level
# 3       Saudi Air Navigation Services   Jeddah 2020-01-06  Mid-Senior level
# 4                                  EY   Riyadh 2020-01-06          Director
# ...                               ...      ...        ...               ...
# 123188                         Unkown   Riyadh 2021-11-12  Mid-Senior level
# 123189                     Xbress.com   Riyadh 2021-11-12  Mid-Senior level
# 123190     SFDA - هيئة الغذاء والدواء   Riyadh 2021-11-11       Entry level
# 123191                      Calo Inc.  Eastern 2021-09-19       Entry level
# 123192                      Flat6Labs   Riyadh 2021-11-11  Mid-Senior level
#
#          industry  experience              department      month
# 0         Finance           0                   sales    January
# 1       Utilities           3                   other    January
# 2          Retail           1         human resources    January
# 3           other           0                   other    January
# 4         Finance           7                 finance    January
# ...           ...         ...                     ...        ...
# 123188      other           0                 finance   November
# 123189      other           3             engineering   November
# 123190  Utilities           0         human resources   November
# 123191  Utilities           1  Information Technology  September
# 123192      other           1                   other   November
#
# [123193 rows x 8 columns]

# %%
sb.catplot(y="industry", hue="level", kind="count",
            palette="dark", edgecolor=".6",
            data=engineering,height=10,aspect=1.6,legend_out=False)
sb.set(font_scale = .5)

# %%
mask = explor[explor.department=='Information Technology']

# %% [markdown]
# ## Research Question 3 (What are the companies that may hire T5 Bootcamp graduates?)

# %%
mask['company'].value_counts().head(20).plot(kind='bar', figsize = (15,8), fontsize = 20);

plt.xlabel('', fontsize=20)
plt.ylabel('Number of job posts', fontsize=20, rotation = 'vertical')
plt.title('IT High demand Companies  \n' , fontsize = 35);

# %% [markdown]
# ## Research Question 4 (what is the Level high required?)

# %%
plt.figure(figsize = [20,8])
base_color =sb.color_palette()[0]
data = mask.level.value_counts()
plt.bar(x = data.index,height= data.values ,color=  base_color, width = .3)
plt.tick_params(labelsize = 20)
plt.xlabel('Job level', fontsize=30)
plt.ylabel('Number of job post', fontsize=30, rotation = 'vertical')
plt.title('IT job post for each level \n', fontsize = 30);

# %%
plt.figure(figsize = [20,8])
base_color =sb.color_palette()[0]
data = mask.industry.value_counts()
plt.bar(x = data.index,height= data.values ,color=  base_color, width = .3)
plt.tick_params(labelsize = 20)
plt.xlabel('Job level', fontsize=30)
plt.ylabel('Number of job post', fontsize=30, rotation = 'vertical')
plt.title('Number of job post for each job level', fontsize = 30);

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > After EDA I notate Labor market has a high demand for IT positions. Also, IT services become a major department in different industries. The mid-senior level is the highest level in demand for different industries, especially in the IT department.
